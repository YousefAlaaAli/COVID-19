# %% [markdown]
# # COVID-19

# %% [markdown]
# ## 1. Defining the problem statement
# Analyze COVID-19 data to understand infection trends and recovery rates by exploring key metrics such as total cases and deaths across different locations and time periods.

# %%
from IPython.display import Image
Image(url= "https://plus.unsplash.com/premium_photo-1661603901299-c8554e8b8678?q=80&w=2072&auto=format&fit=crop&ixlib=rb-4.0.3&ixid=M3wxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8fA%3D%3D")
# Out:
# <img src="https://plus.unsplash.com/premium_photo-1661603901299-c8554e8b8678?q=80&w=2072&auto=format&fit=crop&ixlib=rb-4.0.3&ixid=M3wxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8fA%3D%3D"/>

# %% [markdown]
# ## 2. Import Libraries

# %%
# data analysis and wrangling
import pandas as pd
import numpy as np

# visualization
import seaborn as sns
import matplotlib.pyplot as plt

# warning
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## 3. Collecting the data

# %%
df = pd.read_csv('https://covid.ourworldindata.org/data/owid-covid-data.csv')

# %% [markdown]
# ## 4. Data Preprocessing

# %%
Image(url= "https://images.unsplash.com/photo-1584254520678-31fe4dce5306?q=80&w=2071&auto=format&fit=crop&ixlib=rb-4.0.3&ixid=M3wxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8fA%3D%3D")
# Out:
# <img src="https://images.unsplash.com/photo-1584254520678-31fe4dce5306?q=80&w=2071&auto=format&fit=crop&ixlib=rb-4.0.3&ixid=M3wxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8fA%3D%3D"/>

# %%
df
# Out:
#        iso_code continent     location        date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-01-05          0.0        0.0
# 1           AFG      Asia  Afghanistan  2020-01-06          0.0        0.0
# 2           AFG      Asia  Afghanistan  2020-01-07          0.0        0.0
# 3           AFG      Asia  Afghanistan  2020-01-08          0.0        0.0
# 4           AFG      Asia  Afghanistan  2020-01-09          0.0        0.0
# ...         ...       ...          ...         ...          ...        ...
# 429430      ZWE    Africa     Zimbabwe  2024-07-31     266386.0        0.0
# 429431      ZWE    Africa     Zimbabwe  2024-08-01     266386.0        0.0
# 429432      ZWE    Africa     Zimbabwe  2024-08-02     266386.0        0.0
# 429433      ZWE    Africa     Zimbabwe  2024-08-03     266386.0        0.0
# 429434      ZWE    Africa     Zimbabwe  2024-08-04     266386.0        0.0
#
# ...

# %% [markdown]
# ### 4.1 Analyze by describing data

# %%
df.shape
# Out:
# (429435, 67)

# %%
df.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-01-05          0.0        0.0
# 1      AFG      Asia  Afghanistan  2020-01-06          0.0        0.0
# 2      AFG      Asia  Afghanistan  2020-01-07          0.0        0.0
# 3      AFG      Asia  Afghanistan  2020-01-08          0.0        0.0
# 4      AFG      Asia  Afghanistan  2020-01-09          0.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           0.0         0.0                  NaN  ...
# 1                 NaN           0.0         0.0                  NaN  ...
# 2                 NaN           0.0         0.0                  NaN  ...
# 3                 NaN           0.0         0.0                  NaN  ...
# 4                 NaN           0.0         0.0                  NaN  ...
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# ...

# %%
df.tail()
# Out:
#        iso_code continent  location        date  total_cases  new_cases  \
# 429430      ZWE    Africa  Zimbabwe  2024-07-31     266386.0        0.0
# 429431      ZWE    Africa  Zimbabwe  2024-08-01     266386.0        0.0
# 429432      ZWE    Africa  Zimbabwe  2024-08-02     266386.0        0.0
# 429433      ZWE    Africa  Zimbabwe  2024-08-03     266386.0        0.0
# 429434      ZWE    Africa  Zimbabwe  2024-08-04     266386.0        0.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 429430                 0.0        5740.0         0.0                  0.0
# 429431                 0.0        5740.0         0.0                  0.0
# 429432                 0.0        5740.0         0.0                  0.0
# 429433                 0.0        5740.0         0.0                  0.0
# 429434                 0.0        5740.0         0.0                  0.0
#
#         ...  male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# ...

# %%
df.sample(10)
# Out:
#         iso_code      continent                   location        date  \
# 328665       SPM  North America  Saint Pierre and Miquelon  2022-05-18
# 200700       KWT           Asia                     Kuwait  2020-12-26
# 397956       UGA         Africa                     Uganda  2023-04-20
# 282318  OWID_CYN           Asia            Northern Cyprus  2021-05-05
# 173849       IND           Asia                      India  2020-10-31
# 69915        CAF         Africa   Central African Republic  2023-06-25
# 176698       IDN           Asia                  Indonesia  2024-01-11
# 137160       GMB         Africa                     Gambia  2020-04-11
# 236235       MHL        Oceania           Marshall Islands  2022-07-04
# 87626        CUB  North America                       Cuba  2021-07-22
#
#         total_cases  new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 328665       2739.0        0.0               1.714           1.0         0.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 429435 entries, 0 to 429434
# Data columns (total 67 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   iso_code                                    429435 non-null  object
#  1   continent                                   402910 non-null  object
#  2   location                                    429435 non-null  object
#  3   date                                        429435 non-null  object
#  4   total_cases                                 411804 non-null  float64
#  5   new_cases                                   410159 non-null  float64
#  6   new_cases_smoothed                          408929 non-null  float64
#  7   total_deaths                                411804 non-null  float64
#  8   new_deaths                                  410608 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# iso_code                                        0
# continent                                   26525
# location                                        0
# date                                            0
# total_cases                                 17631
#                                             ...
# population                                      0
# excess_mortality_cumulative_absolute       416024
# excess_mortality_cumulative                416024
# excess_mortality                           416024
# excess_mortality_cumulative_per_million    416024
# Length: 67, dtype: int64

# %%
df.describe()
# Out:
#         total_cases     new_cases  new_cases_smoothed  total_deaths  \
# count  4.118040e+05  4.101590e+05        4.089290e+05  4.118040e+05
# mean   7.365292e+06  8.017360e+03        8.041026e+03  8.125957e+04
# std    4.477582e+07  2.296649e+05        8.661611e+04  4.411901e+05
# min    0.000000e+00  0.000000e+00        0.000000e+00  0.000000e+00
# 25%    6.280750e+03  0.000000e+00        0.000000e+00  4.300000e+01
# 50%    6.365300e+04  0.000000e+00        1.200000e+01  7.990000e+02
# 75%    7.582720e+05  0.000000e+00        3.132860e+02  9.574000e+03
# max    7.758668e+08  4.423623e+07        6.319461e+06  7.057132e+06
#
#           new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  410608.000000        409378.000000            411804.000000
# mean       71.852139            72.060873            112096.199396
# std      1368.322990           513.636567            162240.412419
# min         0.000000             0.000000                 0.000000
# ...

# %% [markdown]
# ## 5. EXPLORING WORLD DATA

# %%
df['location']
# Out:
# 0         Afghanistan
# 1         Afghanistan
# 2         Afghanistan
# 3         Afghanistan
# 4         Afghanistan
#              ...
# 429430       Zimbabwe
# 429431       Zimbabwe
# 429432       Zimbabwe
# 429433       Zimbabwe
# 429434       Zimbabwe
# Name: location, Length: 429435, dtype: object

# %%
df['location'].unique()
# Out:
# array(['Afghanistan', 'Africa', 'Albania', 'Algeria', 'American Samoa',
#        'Andorra', 'Angola', 'Anguilla', 'Antigua and Barbuda',
#        'Argentina', 'Armenia', 'Aruba', 'Asia', 'Australia', 'Austria',
#        'Azerbaijan', 'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados',
#        'Belarus', 'Belgium', 'Belize', 'Benin', 'Bermuda', 'Bhutan',
#        'Bolivia', 'Bonaire Sint Eustatius and Saba',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei', 'Bulgaria', 'Burkina Faso',
#        'Burundi', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde',
#        'Cayman Islands', 'Central African Republic', 'Chad', 'Chile',
#        'China', 'Colombia', 'Comoros', 'Congo', 'Cook Islands',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Curacao',
#        'Cyprus', 'Czechia', 'Democratic Republic of Congo', 'Denmark',
#        'Djibouti', 'Dominica', 'Dominican Republic', 'East Timor',
# ...

# %%
df['location'].nunique()
# Out:
# 255

# %% [markdown]
# ### 5.1 Selecting the 'World' data

# %%
df_world = df[df.location == 'World']

# %%
df_world
# Out:
#         iso_code continent location        date  total_cases  new_cases  \
# 422729  OWID_WRL       NaN    World  2020-01-05          2.0        2.0
# 422730  OWID_WRL       NaN    World  2020-01-06          2.0        0.0
# 422731  OWID_WRL       NaN    World  2020-01-07          2.0        0.0
# 422732  OWID_WRL       NaN    World  2020-01-08          2.0        0.0
# 422733  OWID_WRL       NaN    World  2020-01-09          2.0        0.0
# ...          ...       ...      ...         ...          ...        ...
# 424408  OWID_WRL       NaN    World  2024-08-10          NaN        NaN
# 424409  OWID_WRL       NaN    World  2024-08-11          NaN        NaN
# 424410  OWID_WRL       NaN    World  2024-08-12          NaN        NaN
# 424411  OWID_WRL       NaN    World  2024-08-13          NaN        NaN
# 424412  OWID_WRL       NaN    World  2024-08-14          NaN        NaN
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# ...

# %% [markdown]
# ### 5.2 Finding the date of the maximum number of deaths all over the world

# %%
df_world['new_deaths'].max()
# Out:
# 103719.0

# %%
df_world['total_deaths'].max()
# Out:
# 7057132.0

# %%
df_world [df_world['new_deaths'] == df_world['new_deaths'].max()]
# Out:
#         iso_code continent location        date  total_cases  new_cases  \
# 423114  OWID_WRL       NaN    World  2021-01-24   98650747.0  4227124.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 423114          603874.857     2280859.0    103719.0              14817.0
#
#         ...  male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 423114  ...        34.635                   60.13                       2.705
#
#         life_expectancy  human_development_index  population  \
# 423114            72.58                    0.737  7975105024
#
#         excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 423114                                   NaN                          NaN
#
#         excess_mortality  excess_mortality_cumulative_per_million
# 423114               NaN                                      NaN
#
# [1 rows x 67 columns]

# %%
df_world[df_world['new_deaths'] == df_world['new_deaths'].max()]['date']
# Out:
# 423114    2021-01-24
# Name: date, dtype: object

# %%
df_world['new_deaths'].idxmax()
# Out:
# 423114

# %%
df_world.loc[df_world['new_deaths'].idxmax()]['date']
# Out:
# '2021-01-24'

# %%
df_world[df_world['new_deaths'] == df_world['new_deaths'].min()]
# Out:
#         iso_code continent location        date  total_cases  new_cases  \
# 422730  OWID_WRL       NaN    World  2020-01-06          2.0        0.0
# 422731  OWID_WRL       NaN    World  2020-01-07          2.0        0.0
# 422732  OWID_WRL       NaN    World  2020-01-08          2.0        0.0
# 422733  OWID_WRL       NaN    World  2020-01-09          2.0        0.0
# 422734  OWID_WRL       NaN    World  2020-01-10          2.0        0.0
# ...          ...       ...      ...         ...          ...        ...
# 424397  OWID_WRL       NaN    World  2024-07-30  775819614.0        0.0
# 424398  OWID_WRL       NaN    World  2024-07-31  775819614.0        0.0
# 424399  OWID_WRL       NaN    World  2024-08-01  775819614.0        0.0
# 424400  OWID_WRL       NaN    World  2024-08-02  775819614.0        0.0
# 424401  OWID_WRL       NaN    World  2024-08-03  775819614.0        0.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# ...

# %%
df_world[df_world['new_deaths'] == df_world['new_deaths'].min()]['date']
# Out:
# 422730    2020-01-06
# 422731    2020-01-07
# 422732    2020-01-08
# 422733    2020-01-09
# 422734    2020-01-10
#              ...
# 424397    2024-07-30
# 424398    2024-07-31
# 424399    2024-08-01
# 424400    2024-08-02
# 424401    2024-08-03
# Name: date, Length: 1434, dtype: object

# %%
df_world['new_deaths'].idxmin()
# Out:
# 422730

# %%
df_world.loc[df_world['new_deaths'].idxmin()] ['date']
# Out:
# '2020-01-06'

# %%
df_world['new_deaths'].argmax()
# Out:
# 385

# %%
df_world.iloc[df_world['new_deaths'].argmax()] ['date']
# Out:
# '2021-01-24'

# %%
df_world.iloc[df_world['new_deaths'].argmin()] ['date']
# Out:
# '2020-01-06'

# %% [markdown]
# ### 5.3 Calculating the percentage of confirmed cases regarding the world population

# %%
df_world['population'].unique()
# Out:
# array([7975105024], dtype=int64)

# %%
df_world['total_cases']
# Out:
# 422729    2.0
# 422730    2.0
# 422731    2.0
# 422732    2.0
# 422733    2.0
#          ...
# 424408    NaN
# 424409    NaN
# 424410    NaN
# 424411    NaN
# 424412    NaN
# Name: total_cases, Length: 1684, dtype: float64

# %%
df_world['total_cases'].max()
# Out:
# 775866783.0

# %%
df_world_ratio = df_world['total_cases'].max() / df_world['population'].max()
df_world_ratio
# Out:
# 0.09728608973363158

# %% [markdown]
# ### 5.4 Estimating Recovery Rates

# %%
# Remove rows that contain NaN values in the 'total_cases' or 'total_deaths' columns
df_cleaned = df.dropna(subset=['total_cases', 'total_deaths'])

# Alternatively, replace missing values in 'total_cases' and 'total_deaths' with 0
df['total_cases'] = df['total_cases'].fillna(0)
df['total_deaths'] = df['total_deaths'].fillna(0)

# %%
total_cases_latest = df['total_cases'].max()
total_cases_latest
# Out:
# 775866783.0

# %%
total_deaths_latest = df['total_deaths'].max()
total_deaths_latest
# Out:
# 7057132.0

# %%
total_recovered_latest = total_cases_latest - total_deaths_latest
total_recovered_latest
# Out:
# 768809651.0

# %% [markdown]
# ## 6. VISUALIZING WORLD DATA

# %% [markdown]
# ### Confirmed cases (Total Cases) all over the world

# %%
df_world_over_time = df_world.groupby(["date"])[["total_cases","new_cases","total_deaths","new_deaths"]].sum()
df_world_over_time
# Out:
#             total_cases  new_cases  total_deaths  new_deaths
# date
# 2020-01-05          2.0        2.0           3.0         3.0
# 2020-01-06          2.0        0.0           3.0         0.0
# 2020-01-07          2.0        0.0           3.0         0.0
# 2020-01-08          2.0        0.0           3.0         0.0
# 2020-01-09          2.0        0.0           3.0         0.0
# ...                 ...        ...           ...         ...
# 2024-08-10          0.0        0.0           0.0         0.0
# 2024-08-11          0.0        0.0           0.0         0.0
# 2024-08-12          0.0        0.0           0.0         0.0
# 2024-08-13          0.0        0.0           0.0         0.0
# 2024-08-14          0.0        0.0           0.0         0.0
#
# [1684 rows x 4 columns]

# %%
df_world_over_time = df_world.groupby(["date"])[["total_cases","new_cases","total_deaths","new_deaths"]].sum().reset_index()
df_world_over_time
# Out:
#             date  total_cases  new_cases  total_deaths  new_deaths
# 0     2020-01-05          2.0        2.0           3.0         3.0
# 1     2020-01-06          2.0        0.0           3.0         0.0
# 2     2020-01-07          2.0        0.0           3.0         0.0
# 3     2020-01-08          2.0        0.0           3.0         0.0
# 4     2020-01-09          2.0        0.0           3.0         0.0
# ...          ...          ...        ...           ...         ...
# 1679  2024-08-10          0.0        0.0           0.0         0.0
# 1680  2024-08-11          0.0        0.0           0.0         0.0
# 1681  2024-08-12          0.0        0.0           0.0         0.0
# 1682  2024-08-13          0.0        0.0           0.0         0.0
# 1683  2024-08-14          0.0        0.0           0.0         0.0
#
# [1684 rows x 5 columns]

# %%
# Using line-plot

plt.figure(figsize=(20,10))  

#plt.plot(df_world_over_time['date'], df_world_over_time['total_cases'])
plt.plot(df_world_over_time.index, df_world_over_time['total_cases'])

plt.title('Evolution of Confirmed Covid-19 cases over time in the world', fontsize=16)
plt.xlabel('No. of days', fontsize=16)
plt.ylabel('Confirmed cases', fontsize=1)
plt.show()

# %%
# Using line-plot
plt.figure(figsize=(20,10))
plt.plot(df_world_over_time['date'], df_world_over_time['total_deaths'])

#plt.plot(df_world_over_time.index, df_world_over_time['total_deaths'])

plt.title('Evolution of Confirmed Covid-19 cases over time in the world', fontsize=16)
plt.xlabel('Year', fontsize=16)
plt.ylabel('Confirmed cases', fontsize=16)
plt.show()

# %%
df_world_over_time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1684 entries, 0 to 1683
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          1684 non-null   object
#  1   total_cases   1684 non-null   float64
#  2   new_cases     1684 non-null   float64
#  3   total_deaths  1684 non-null   float64
#  4   new_deaths    1684 non-null   float64
# dtypes: float64(4), object(1)
# memory usage: 65.9+ KB

# %%
df_world_over_time['date'] = pd.to_datetime(df_world_over_time['date'])

# %%
df_world_over_time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1684 entries, 0 to 1683
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          1684 non-null   datetime64[ns]
#  1   total_cases   1684 non-null   float64
#  2   new_cases     1684 non-null   float64
#  3   total_deaths  1684 non-null   float64
#  4   new_deaths    1684 non-null   float64
# dtypes: datetime64[ns](1), float64(4)
# memory usage: 65.9 KB

# %% [markdown]
# ### Total deaths cases evolution over time

# %%
# Using line-plot
plt.figure(figsize=(20,10))

#plt.plot(df_world_over_time.index, df_world_over_time['total_deaths'])
plt.plot(df_world_over_time['date'], df_world_over_time['total_cases'])

plt.title('Evolution of Covid-19 Deaths cases over time in the world', fontsize=16)
plt.xlabel('Year', fontsize=16)
plt.ylabel('Number of Deaths', fontsize=16)
# Out:
# Text(0, 0.5, 'Number of Deaths')

# %% [markdown]
# ### New cases all over the world

# %%
# Using line-plot
plt.figure(figsize=(12,5))
#plt.bar(df_world_over_time.index, df_world_over_time['new_cases'])
plt.plot(df_world_over_time['date'], df_world_over_time['total_cases'])

plt.title('Evolution of Covid-19 New Cases over time in the world', fontsize=16)
plt.xlabel('Year', fontsize=16)
plt.ylabel('New Cases', fontsize=16)
# Out:
# Text(0, 0.5, 'New Cases')

# %% [markdown]
# ### Calculate Total Recovered

# %%
# Calculate total_recovered
df_world_over_time['total_recovered'] = df_world_over_time['total_cases'] - df_world_over_time['total_deaths']

# Create the line plot
plt.figure(figsize=(20, 10))
plt.plot(df_world_over_time['date'], df_world_over_time['total_recovered'], label='Total Recovered', color='green')

# Add title and labels
plt.title('Evolution of Covid-19 Recovered Cases Over Time in the World', fontsize=16)
plt.xlabel('Year', fontsize=16)
plt.ylabel('Number of Recovered Cases', fontsize=16)
plt.legend()  # Show the legend
plt.grid(True)  # Enable grid for better visualization

# Display the plot
plt.show()

# %% [markdown]
# ### Putting it all together

# %%
# Using line-plot
plt.figure(figsize=(20,10))
#plt.plot(df_world_over_time.index, df_world_over_time['total_cases'], label='Confirmed')
plt.plot(df_world_over_time.index, df_world_over_time['total_deaths'], label='Total Deaths')
plt.plot(df_world_over_time.index, df_world_over_time['new_cases'], label='New')
plt.plot(df_world_over_time.index, df_world_over_time['new_deaths'], label='New Deaths')
plt.legend(loc=0)
plt.show()
